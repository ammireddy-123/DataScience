# %%
import pandas as pd

# %%
s = pd.Series([9,8,7,6], index=[1,2,3,4])

# %%
s
# Out:
# 1    9
# 2    8
# 3    7
# 4    6
# dtype: int64

# %%
s=pd.Series([11,22,33,44] , index=['a','b','c','d'])

# %%
s
# Out:
# a    11
# b    22
# c    33
# d    44
# dtype: int64

# %%
data={'Country' : ['Belgium','India','Brazil'] , 'Captail': ['Brussels','New Delhi','Brasilia'] , 'Population': [11111,22222,33333]}

# %%
data
# Out:
# {'Country': ['Belgium', 'India', 'Brazil'],
#  'Captail': ['Brussels', 'New Delhi', 'Brasilia'],
#  'Population': [11111, 22222, 33333]}

# %%
df = pd.DataFrame(data,columns=['Country','Captail','Population'])

# %%
df
# Out:
#    Country    Captail  Population
# 0  Belgium   Brussels       11111
# 1    India  New Delhi       22222
# 2   Brazil   Brasilia       33333

# %%
df.to_csv('mydataframe.csv')

# %%
s['b']
# Out:
# 22

# %%
df[1:]
# Out:
#   Country    Captail  Population
# 1   India  New Delhi       22222
# 2  Brazil   Brasilia       33333

# %%
df[:1]
# Out:
#    Country   Captail  Population
# 0  Belgium  Brussels       11111

# %%
df[0:]
# Out:
#    Country    Captail  Population
# 0  Belgium   Brussels       11111
# 1    India  New Delhi       22222
# 2   Brazil   Brasilia       33333

# %%
df[2:]
# Out:
#   Country   Captail  Population
# 2  Brazil  Brasilia       33333

# %%
df[:2]
# Out:
#    Country    Captail  Population
# 0  Belgium   Brussels       11111
# 1    India  New Delhi       22222

# %%
df[:3]
# Out:
#    Country    Captail  Population
# 0  Belgium   Brussels       11111
# 1    India  New Delhi       22222
# 2   Brazil   Brasilia       33333

# %%
df.iloc[[0],[1]]
# Out:
#     Captail
# 0  Brussels

# %%
df.iloc[[1],[1]]
# Out:
#      Captail
# 1  New Delhi

# %%
df.iloc[[2],[0]]
# Out:
#   Country
# 2  Brazil

# %%
df.iloc[[0],[2]]
# Out:
#    Population
# 0       11111

# %%
df.loc[[0],['Country']]
# Out:
#    Country
# 0  Belgium

# %%
df.loc[[2],['Captail']]
# Out:
#     Captail
# 2  Brasilia

# %%
s[~(s>1)]
# Out:
# Series([], dtype: int64)

# %%
s[(s<-1) | (s > 2)]
# Out:
# a    11
# b    22
# c    33
# d    44
# dtype: int64

# %%
df[df['Population']> 12000]
# Out:
#   Country    Captail  Population
# 1   India  New Delhi       22222
# 2  Brazil   Brasilia       33333

# %%
s['a']=6

# %%
s
# Out:
# a     6
# b    22
# c    33
# d    44
# dtype: int64

# %%
s['a'] = 11

# %%
s
# Out:
# a    11
# b    22
# c    33
# d    44
# dtype: int64

# %%
s.drop(['d'])
# Out:
# a    11
# b    22
# c    33
# dtype: int64

# %%
s
# Out:
# a    11
# b    22
# c    33
# d    44
# dtype: int64

# %%
s.drop(['a','c'])
# Out:
# b    22
# d    44
# dtype: int64

# %%
s
# Out:
# a    11
# b    22
# c    33
# d    44
# dtype: int64

# %%
df.drop('Country', axis = 1)
# Out:
#      Captail  Population
# 0   Brussels       11111
# 1  New Delhi       22222
# 2   Brasilia       33333

# %%
df
# Out:
#    Country    Captail  Population
# 0  Belgium   Brussels       11111
# 1    India  New Delhi       22222
# 2   Brazil   Brasilia       33333

# %%
df.sort_index()
# Out:
#    Country    Captail  Population
# 0  Belgium   Brussels       11111
# 1    India  New Delhi       22222
# 2   Brazil   Brasilia       33333

# %%
df.sort_values(by='Country')
# Out:
#    Country    Captail  Population
# 0  Belgium   Brussels       11111
# 2   Brazil   Brasilia       33333
# 1    India  New Delhi       22222

# %%
df.sort_values(by='Captail')
# Out:
#    Country    Captail  Population
# 2   Brazil   Brasilia       33333
# 0  Belgium   Brussels       11111
# 1    India  New Delhi       22222

# %%
df.rank()
# Out:
#    Country  Captail  Population
# 0      1.0      2.0         1.0
# 1      3.0      3.0         2.0
# 2      2.0      1.0         3.0

# %%
df.shape
# Out:
# (3, 3)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['Country', 'Captail', 'Population'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     3 non-null      object
#  1   Captail     3 non-null      object
#  2   Population  3 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df.count()
# Out:
# Country       3
# Captail       3
# Population    3
# dtype: int64

# %%
df.sum()
# Out:
# Country              BelgiumIndiaBrazil
# Captail       BrusselsNew DelhiBrasilia
# Population                        66666
# dtype: object

# %%
df.cumsum()
# Out:
#               Country                    Captail  Population
# 0             Belgium                   Brussels       11111
# 1        BelgiumIndia          BrusselsNew Delhi       33333
# 2  BelgiumIndiaBrazil  BrusselsNew DelhiBrasilia       66666

# %%
df.max()
# Out:
# Country           India
# Captail       New Delhi
# Population        33333
# dtype: object

# %%
df.describe()
# Out:
#        Population
# count         3.0
# mean      22222.0
# std       11111.0
# min       11111.0
# 25%       16666.5
# 50%       22222.0
# 75%       27777.5
# max       33333.0

# %%
df.describe()
# Out:
#        Population
# count         3.0
# mean      22222.0
# std       11111.0
# min       11111.0
# 25%       16666.5
# 50%       22222.0
# 75%       27777.5
# max       33333.0

# %%
df.mean()
# Out:
# <ipython-input-80-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Population    22222.0
# dtype: float64

# %%
df.median()
# Out:
# <ipython-input-81-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Population    22222.0
# dtype: float64

# %%
df.mode()
# Out:
#    Country    Captail  Population
# 0  Belgium   Brasilia       11111
# 1   Brazil   Brussels       22222
# 2    India  New Delhi       33333

# %%
f = lambda x: x*2

# %%
f
# Out:
# <function __main__.<lambda>(x)>

# %%
df.apply(f)
# Out:
#           Country             Captail  Population
# 0  BelgiumBelgium    BrusselsBrussels       22222
# 1      IndiaIndia  New DelhiNew Delhi       44444
# 2    BrazilBrazil    BrasiliaBrasilia       66666

# %%
df
# Out:
#    Country    Captail  Population
# 0  Belgium   Brussels       11111
# 1    India  New Delhi       22222
# 2   Brazil   Brasilia       33333

# %%
df.applymap(f)
# Out:
#           Country             Captail  Population
# 0  BelgiumBelgium    BrusselsBrussels       22222
# 1      IndiaIndia  New DelhiNew Delhi       44444
# 2    BrazilBrazil    BrasiliaBrasilia       66666

# %%
s3 = pd.Series([7,-2,3], index=['a','b','d'])

# %%
s3
# Out:
# a    7
# b   -2
# d    3
# dtype: int64

# %%
s+s3
# Out:
# a    18.0
# b    20.0
# c     NaN
# d    47.0
# dtype: float64

# %%
s
# Out:
# a    11
# b    22
# c    33
# d    44
# dtype: int64

# %%
s.add(s3,fill_value=0)
# Out:
# a    18.0
# b    20.0
# c    33.0
# d    47.0
# dtype: float64

# %%
s
# Out:
# a    11
# b    22
# c    33
# d    44
# dtype: int64

# %%
s.sub(s3)
# Out:
# a     4.0
# b    24.0
# c     NaN
# d    41.0
# dtype: float64

# %%
s.sub(s3,fill_value=33)
# Out:
# a     4.0
# b    24.0
# c     0.0
# d    41.0
# dtype: float64

# %%
s.mul(s3,fill_value=1)
# Out:
# a     77.0
# b    -44.0
# c     33.0
# d    132.0
# dtype: float64

# %%
s.div(s3,fill_value=s[2])
# Out:
# a     1.571429
# b   -11.000000
# c     1.000000
# d    14.666667
# dtype: float64

# %%
df2 = pd.DataFrame({'a': [4,5,6], 'b' : [1,2,3], 'c' : [7,8,9]})

# %%
df2
# Out:
#    a  b  c
# 0  4  1  7
# 1  5  2  8
# 2  6  3  9

# %%
df
# Out:
#    Country    Captail  Population
# 0  Belgium   Brussels       11111
# 1    India  New Delhi       22222
# 2   Brazil   Brasilia       33333

# %%
df2= pd.DataFrame([[4,5,6],[1,2,3],[7,8,9]], index=[1,2,3], columns=['aa','bb','cc'])

# %%
df2
# Out:
#    aa  bb  cc
# 1   4   5   6
# 2   1   2   3
# 3   7   8   9

# %%
index = pd.MultiIndex.from_tuples([('d',1) , ('d',2), ('d',3)])

# %%
index
# Out:
# MultiIndex([('d', 1),
#             ('d', 2),
#             ('d', 3)],
#            )

# %%
df2
# Out:
#    aa  bb  cc
# 1   4   5   6
# 2   1   2   3
# 3   7   8   9

# %%
df
# Out:
#    Country    Captail  Population
# 0  Belgium   Brussels       11111
# 1    India  New Delhi       22222
# 2   Brazil   Brasilia       33333

# %%
df2
# Out:
#    aa  bb  cc
# 1   4   5   6
# 2   1   2   3
# 3   7   8   9
